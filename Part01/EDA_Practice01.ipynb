# %% [markdown]
# # ПРАКТИКА-01. Работа в Google Colab
# ---
# - Работа с данными в среде Google Colab (Jupyter Notebook).
# - Знакомство с пакетом Pandas.
# - Работа с табличными данными.

# %% [markdown]
# ## Работа с данными в среде Google Colab (Jupyter Notebook)
# ---
#
# - Знакомство с Google Colab.
# - Работа с блокнотами. Структурирование и разметка информации в блокноте
# - Работа с кодом

# %% [markdown]
# ### Знакомство с Google Colab:
#
# Зайдем в Google Colab и познакомимся с его возможностями: https://colab.research.google.com/#scrollTo=JQesyTg7QSU- .

# %% [markdown]
# ### Работа с блокнотами. Структурирование и разметка информации в блокноте
# ---
# - Зайдем в гугловскую учетку (*.gmal.com);
# - Загрузим блокнот на Google Disk;
# - Перейдем на Google Disk;
# - Свяжем файлы с расширением ipynb с Google Colab;
# - Создадим новый блокнот.
# - создадим структруру блокнота.
# - напишем простой код.

# %%
print("Привет!")
# Out:
# Привет!

# %% [markdown]
# ## Знакомство с пакетом Pandas
# ---
#
# - импорт пакетов программ
# - назначение и структура пакета pandas
# - основные структуры данных и основные операции в Pandas

# %% [markdown]
# ### Импорт pandas

# %%
import pandas as pd

# %% [markdown]
# ### Знакомство с padnas
# ---
#
# https://pandas.pydata.org/docs/user_guide/index.html

# %% [markdown]
# ## Работа с табличными данными
# ---
#
# - загрузка таблиц из *.xlsx
# - загрузка таблиц из *.csv
# - первичный анализ с использованием pandas
#
# https://pandas.pydata.org/docs/user_guide/io.html

# %% [markdown]
# ### Загрузка данных из сессионного хранилища
# ---
#
# - Загрзим файл LinAlg-2.xlsx на диск компьютера из репозитория: https://github.com/garry-nn/Education_DA/tree/main
# - Загрзим файл  в сессионное хранилище
# - Загрузим данные из файла

# %%
data = pd.read_excel("LinAlg-2.xlsx")
data.head()
# Out:
#        Имя Отчество или второе имя Учреждение  \
# 0    Anton                     NaN        NaN
# 1   Negoda                     NaN        NaN
# 2  Michael                     NaN        Dom
# 3   Dmitry                     NaN        NaN
# 4   Nikita                     NaN        СФУ
#
#   Тест:Входное тестирование по алгебре матриц (бонус) (Значение)  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
#   Тест:2.1. Введение в общую алгебру (тест) (Значение)  \
# 0                                               4.08
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
# ...
